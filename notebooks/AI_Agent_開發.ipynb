# %% [markdown]
# # AI Agent 開發筆記本
#
# 在 **Cursor** 裡：
#
# 1. 安裝擴充功能 **Jupyter**（Microsoft）。
# 2. 雙擊本檔，以筆記本編輯器開啟。
# 3. 右上角選 **核心 (Kernel)** → `Python 3`（建議選 `miniconda3` 的解譯器）。
# 4. `Shift+Enter` 執行儲存格。
#
# 終端機啟動傳統網頁介面：
# `python -m jupyter notebook --notebook-dir=C:\Users\User\.cursor-tutor\notebooks`
